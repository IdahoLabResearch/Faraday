# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'server.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

from warehouse.models import Node, Class, Ontology, Relationship 


tree = {
    "name": "Impedance",
    "cls": "Type",
    "ontology": "H2NEW",
    "children": [
        {
            "name": "5-11-22-2A",
            "cls": "Batch",
            "ontology": "H2NEW",
            "children": [
                {
                    "name": "BC-7",
                    "cls": "Cell",
                    "ontology": "H2NEW",
                    "children": []
                },
                {
                    "name": "BC-12",
                    "cls": "Cell",
                    "ontology": "H2NEW",
                    "children": []
                }
            ]
        }
    ]
}

leaf = {
    "name": "BC-7",
    "cls": "Cell",
    "ontology": "H2NEW",
    "children": []
}

rels = Relationship.objects.filter(target__name="BC-7")
print(rels)
# Out:
# <QuerySet [<Relationship: Batch 5-11-22-2A -> Cell BC-7>, <Relationship: Batch 1-14-22-3A -> Cell BC-7>, <Relationship: Batch 5-11-22-5A -> Cell BC-7>]>
